# %%
from neo4j import GraphDatabase
import pandas as pd
import numpy as np
import tensorflow as tf
# import tensorflow_probability as tfp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
uri = "bolt://34.101.159.175:7687"
username = "neo4j"
password = "unej1234"

driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
with driver.session() as session:
    result = session.run("MATCH (n) RETURN n.Vector AS vector, n.label AS label")
    df = pd.DataFrame([record.values() for record in result], columns=result.keys())

# %%
df
# Out:
#                                                 vector  \
# 0    [-0.48007139563560486, 0.6460448503494263, -0....
# 1    [0.26170042157173157, 0.07159162312746048, 0.0...
# 2    [0.022821197286248207, 0.3413693904876709, -0....
# 3    [-0.0965781956911087, 0.03939099982380867, -0....
# 4    [0.39404162764549255, -0.3328622579574585, 0.4...
# ..                                                 ...
# 100  [0.6989031434059143, -0.3856666088104248, 0.55...
# 101  [0.4118303656578064, -0.5445472598075867, -0.1...
# 102  [-0.4613795280456543, 0.18603742122650146, 0.3...
# 103  [-0.24614253640174866, 0.1480824500322342, -0....
# 104  [1.881150245666504, 0.12370976060628891, -2.46...
#
#                                        label
# 0                                  Metalaxyl
# 1                               Gosong bulir
# 2            Acidovorax avenae subsp. avenae
# 3                               Tanaman layu
# 4                                 Bibit mati
# ...

# %%
vector = df["vector"].values.flatten()

# %%
vector
# Out:
# array([list([-0.48007139563560486, 0.6460448503494263, -0.9931934475898743, -0.017790231853723526, 0.6084267497062683, 0.49077683687210083, -0.8700131177902222, -0.43610212206840515, -0.8676986694335938, -1.7821745872497559]),
#        list([0.26170042157173157, 0.07159162312746048, 0.04994821548461914, -0.5911588668823242, 2.2289512157440186, 0.2215389758348465, -0.7910683155059814, -1.2279253005981445, -0.12122853845357895, -1.0645424127578735]),
#        list([0.022821197286248207, 0.3413693904876709, -0.403293639421463, -0.7203349471092224, -0.0651458203792572, -0.41412273049354553, -0.45606517791748047, -0.0075508467853069305, -0.9350470900535583, -1.0907484292984009]),
#        list([-0.0965781956911087, 0.03939099982380867, -0.10253782570362091, -0.9058748483657837, 0.3028155565261841, -0.7179144620895386, -0.35338398814201355, -0.14318008720874786, -0.644025981426239, -1.4506018161773682]),
# ...

# %%
label = df["label"].values

# %%
label
# Out:
# array(['Metalaxyl', 'Gosong bulir', 'Acidovorax avenae subsp. avenae',
#        'Tanaman layu', 'Bibit mati', 'Metil tiofonat', 'Garis Merah',
#        'Propiconazole', 'Akar menghilang', 'Tungro', 'Rhizoctonia solani',
#        'Belatung Lalat Bibit', 'Kasugamisin', 'Steinernema feltiae',
#        'Pelepah mengalami kerusakan', 'Carbendazim', 'Difenoconazole',
#        'Kuprum', 'Bulir mengalami kerusakan', 'Magnaporthe oryzae',
#        'Pythium spp.', 'Ganjur Padi Asia', 'Fluazinam',
#        'Batang mengalami kerusakan', 'Pelepah membusuk',
#        'Tanaman tumbuh terhambat', 'Daun berlubang', 'Organofosfat',
#        'Piretroid', 'Puccinia striiformis', 'Neonicotinoid',
#        'Malai terdapat bercak', 'Tricyclazole', 'Blas', 'Strobilurin',
#        'Lepuh Daun', 'Burkholderia glumae', 'Luka abu abu hijau',
#        'Tanaman mengeluarkan cairan', 'Bulir terdapat bercak',
#        'Daun mengering', 'Daun mengalami kerusakan',
# ...

# %%
vectorize_label = pd.DataFrame({'Label': label, 'Vector': vector})

# %%
vectorize_label
# Out:
#                                        Label  \
# 0                                  Metalaxyl
# 1                               Gosong bulir
# 2            Acidovorax avenae subsp. avenae
# 3                               Tanaman layu
# 4                                 Bibit mati
# ..                                       ...
# 100  Bacillus thuringiensis var. israelensis
# 101                           Belalang Sawah
# 102                       Bakteri Garis Daun
# 103                            Fusarium spp.
# 104                            Daun berkarat
#
#                                                 Vector
# 0    [-0.48007139563560486, 0.6460448503494263, -0....
# 1    [0.26170042157173157, 0.07159162312746048, 0.0...
# 2    [0.022821197286248207, 0.3413693904876709, -0....
# 3    [-0.0965781956911087, 0.03939099982380867, -0....
# 4    [0.39404162764549255, -0.3328622579574585, 0.4...
# ..                                                 ...
# ...
